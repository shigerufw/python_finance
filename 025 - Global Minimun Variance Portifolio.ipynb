# %% [markdown]
# # This notebook we're going to see:
# <ul>
#     <li>finding the GMV
#     </li>
#     <li>Using a Minimizer to set weights</li>
# </ul>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_datareader as web
import datetime
import risk_kit as erk
import seaborn as sns
# %matplotlib inline

# %%
# auto reload imported modules
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ind = erk.get_ind_returns()
er = erk.annualize_rets(ind['1996':'2000'], 12)
cov = ind['1996':'2000'].cov()

# %%
erk.msr

# %%
l = ["Food",'Steel']
erk.msr(0.1,er[l], cov.loc[l,l])
# Out:
# array([0.75040362, 0.24959638])

# %%
er[l]

# %%
#predict .11 food and .12 steel (not so much different of real ones)
erk.msr(0.1,np.array([.11,.12]),cov.loc[l,l])
# Out:
# array([0.57930354, 0.42069646])

# %% [markdown]
# if you change a little bit you cause a big pertubation, error maximizing of markovits

# %% [markdown]
# ### Markovits max sharpe ratio portifolio

# %%
erk.plot_ef(20, er, cov, show_cml = True, riskfree_rate = 0.1)

# %% [markdown]
# ### Naive Portifolio (weights/n) and GMV

# %%
erk.plot_ef(40, er,cov, show_cml=True, show_gmv=True, show_ew=True, riskfree_rate= 0.1)

# %%
erk.gmv(cov.loc[l,l])
# Out:
# array([0.73822434, 0.26177566])
